# %%
import pandas as pd
import numpy as np

db = pd.read_excel('eula_code.xlsx', index_col='country_two_code')
data_db = db[db['terms_code'].isna()==False]

# %%
data_db['terms_code'] = data_db['terms_code'].map(lambda x : x.split(', '))
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_6628\232831958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_db['terms_code'] = data_db['terms_code'].map(lambda x : x.split(', '))

# %%
data_db
# Out:
#                  country_three_code country_info  \
# country_two_code
# KR                              KOR        Korea
# US                              USA          USA
#
#                                                          terms_code
# country_two_code
# KR                [S_SVC, S_PRV, S_PRM, S_PRC, S_PRD, S_VDC, S_VDD]
# US                       [S_SVC, S_PRG, S_ADG, S_VNG, S_TAG, S_VRC]

# %%
data_db.to_json('eula.json', orient='index',indent=4)

# %%
import json

with open('eula.json', 'r') as j :
    contents = json.loads(j.read())

# %%
contents.keys()
# Out:
# dict_keys(['KR', 'US'])

# %%
retObj = {
    "subscribed": False,
    "launchPoints": [
        {
            "mediumLargeIcon": "",
            "bgColor": "",
            "installTime": 0,
            "userData": "",
            "systemApp": True,
            "appDescription": "",
            "launchPointId": "com.webos.app.homeoffice_default",
            "qCardTitle": "Home Office",
            "bgImages": [
            ],
            "lptype": "default",
            "relaunch": False,
            "favicon": "",
            "icon": "/usr/palm/applications/com.webos.app.homeoffice/ic_app_homeoffice.png",
            "id": "com.webos.app.homeoffice",
            "bgImage": "/usr/palm/applications/com.webos.app.homeoffice/img_splash_homeoffice_01.png",
            "title": "Home Office",
            "largeIcon": "/usr/palm/applications/com.webos.app.homeoffice/ic_app_homeoffice.png",
            "iconColor": "#3CA0A8",
            "tileSize": "normal",
            "removable": False,
            "params": {
            },
            "unmovable": False,
            "extraLargeIcon": "/usr/palm/applications/com.webos.app.homeoffice/ic_app_homeoffice.png",
            "qCardImage": "/media/system/qcards/com.webos.app.homeoffice/sys-assets/1920x1080/bg_qcard.png",
            "imageForRecents": "/usr/palm/applications/com.webos.app.homeoffice/img_splash_homeoffice_01.png",
            "miniicon": "",
            "qCardDescription": "Work on a large screen"
        },
        {
            "mediumLargeIcon": "",
            "bgColor": "",
            "installTime": 0,
            "userData": "",
            "systemApp": True,
            "appDescription": "",
            "launchPointId": "com.webos.app.totalmusic_default",
            "qCardTitle": "Music",
            "bgImages": [
            ],
            "lptype": "default",
            "relaunch": False,
            "favicon": "",
            "icon": "/usr/palm/applications/com.webos.app.totalmusic/sys-assets/app_icon_music.png",
            "id": "com.webos.app.totalmusic",
            "bgImage": "/usr/palm/applications/com.webos.app.totalmusic/sys-assets/splash_music.png",
            "title": "Music",
            "largeIcon": "/usr/palm/applications/com.webos.app.totalmusic/sys-assets/app_icon_music.png",
            "iconColor": "#7d54b0",
            "tileSize": "normal",
            "removable": False,
            "params": {
            },
            "unmovable": False,
            "extraLargeIcon": "/usr/palm/applications/com.webos.app.totalmusic/sys-assets/app_icon_music_large.png",
            "qCardImage": "/media/system/qcards/com.webos.app.totalmusic/sys-assets/1920x1080/bg_qcard.png",
            "imageForRecents": "/usr/palm/applications/com.webos.app.totalmusic/sys-assets/splash_music.png",
            "miniicon": "",
            "qCardDescription": "Enjoy various songs"
        },
        {
            "mediumLargeIcon": "",
            "bgColor": "",
            "installTime": 0,
            "userData": "",
            "systemApp": True,
            "appDescription": "",
            "launchPointId": "com.webos.app.homeconnect_default",
            "qCardTitle": "Home Hub",
            "bgImages": [
            ],
            "lptype": "default",
            "relaunch": False,
            "favicon": "",
            "icon": "/usr/palm/applications/com.webos.app.homeconnect/icon.png",
            "id": "com.webos.app.homeconnect",
            "bgImage": "/usr/palm/applications/com.webos.app.homeconnect/splash.png",
            "title": "Home Hub",
            "largeIcon": "/usr/palm/applications/com.webos.app.homeconnect/icon.png",
            "iconColor": "#5e7bce",
            "tileSize": "normal",
            "removable": False,
            "params": {
            },
            "unmovable": False,
            "extraLargeIcon": "/usr/palm/applications/com.webos.app.homeconnect/icon_large.png",
            "qCardImage": "/media/system/qcards/com.webos.app.homeconnect/sys-assets/1920x1080/bg_qcard.png",
            "imageForRecents": "/usr/palm/applications/com.webos.app.homeconnect/recent.png",
            "miniicon": "",
            "qCardDescription": "A hub of the smart home"
        }
    ],
    "returnValue": True
}

# %%
qcardlist = retObj['launchPoints']
for qcard in qcardlist :
    print(qcard['title'])
# Out:
# Home Office
# Music
# Home Hub

# %%
import json

def OpenJsonFile(file) :
    with open(file, 'r') as file :
        data = json.loads(file.read())

    return data
    
def MergeData() :
    JsonList = ['eula.json', 'qcard.json', 'hotkey.json']
    basedata = dict()
    
    for json in JsonList :
        data = OpenJsonFile(json)
        for cntrycode, value in data.items() :
            if cntrycode in basedata.keys() :
                for key in data[cntrycode].keys() :
                    if key.lower() not in basedata[cntrycode].keys() :
                        basedata[cntrycode][key] = data[cntrycode][key]
            else:
                basedata[cntrycode] = value

    return basedata

# %%
import pandas as pd
import json

def ParsingData(df) :
    return df['App'] + ':' + df['On/Off']

hotkey = pd.read_excel('Hot key.xlsx', sheet_name='RemoteControlMgmt_S23Y')
pubHotkey = hotkey[hotkey['Status'] == 'Publish'][['Country-Code', 'Country', 'App','On/Off']].reset_index(drop=True)
pubHotkey['app_id:isActive'] = pubHotkey.apply(ParsingData, axis=1)

pubHk = pubHotkey[['Country-Code', 'Country', 'app_id:isActive']]
pubDB = pubHk.groupby(['Country-Code','Country'], as_index=False).agg(lambda x : ', '.join(set(x))).set_index('Country-Code')

pubDB['app_id:isActive'] = pubDB['app_id:isActive'].map(lambda x: x.split(', '))
pubDB.to_json('hotkey.json', orient='index', indent=4)
# Out:
# c:\Python311\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
# ===== hotkey.json ===== #

from collections import defaultdict 
import pandas as pd
import json

hotkey = pd.read_excel('Hot key.xlsx',sheet_name='RemoteControlMgmt_S23Y')
hotkey['On/Off'] = hotkey['On/Off'].replace({'On':'True', 'Off':'False'})
pubHotkey = hotkey[hotkey['Status'] == 'Publish'][['Country-Code','Key', 'App', 'On/Off']].reset_index(drop=True)
pubHotkey = pubHotkey.rename({'App':'app_id', 'On/Off':'isActive'}, axis=1)
grouped = pubHotkey.groupby(['Country-Code'])

result = {}

for name, group in grouped :
    result[name[0]] = defaultdict(list)
    result[name[0]]["HotKey"] = {}
    for i in range(len(group)) :
        result[name[0]]['HotKey'][group.iloc[i]['Key']] = []
        result[name[0]]['HotKey'][group.iloc[i]['Key']].append(
            {
                'app_id' : group.iloc[i]['app_id'],
                'isActive' : group.iloc[i]['isActive'],
            }
        )
        
with open('hotkey.json', 'w') as file :
    json.dump(result, file, indent=4)

# =========================== #

# how to access # 
result['US']['HotKey']['new'][0]
# Out:
# c:\Python311\Lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
param = result['US']['HotKey']
param['new'][0]
# Out:
# {'app_id': 'com.webos.app.livetv', 'isActive': 'False'}

# %%
# ============ merge json for auto test ================ #

import json

def OpenJsonFile(file) :
    with open(file, 'r') as file :
        data = json.loads(file.read())

    return data
    
def MergeData() :
    JsonList = ['eula.json', 'qcard.json', 'hotkey.json']
    basedata = dict()
    
    for json in JsonList :
        data = OpenJsonFile(json)
        for cntrycode, value in data.items() :
            if cntrycode in basedata.keys() :
                for key in data[cntrycode].keys() :
                    if key.lower() not in basedata[cntrycode].keys() :
                        basedata[cntrycode][key] = data[cntrycode][key]
            else:
                basedata[cntrycode] = value

    return basedata


d =  MergeData()
jd = json.dumps(d, indent=4)
print(jd)
# Out:
# {
#     "KR": {
#         "country_three_code": "KOR",
#         "country_info": "Korea",
#         "terms_code": [
#             "S_SVC",
#             "S_PRV",
#             "S_PRM",
#             "S_PRC",
#             "S_PRD",
#             "S_VDC",
#             "S_VDD"
#         ],
#         "Q-Card Title": [
#             "Home Office",
#             "Home Hub",
#             "Music"
#         ],
#         "HotKey": {
#             "new": [
#                 {
#                     "app_id": "com.webos.app.lgchannels",
#                     "isActive": "False"
#                 }
#             ],
#             "netflix": [
#                 {
#                     "app_id": "netflix",
#                     "isActive": "True"
#                 }
#             ],
#             "wavve": [
#                 {
#                     "app_id": "pooq",
#                     "isActive": "True"
#                 }
#             ],
#             "amazon": [
#                 {
# ...

# %%
import json 

data = {
    "returnValue": True,
    "serverResponse": {
        "code": "200",
        "message": "OK",
        "response": "{ \"voiceFramework\": { \"voiceKeyBindings\": { \"webOSVoice\": [ \"thinQtv\" ], \"webOSAmazon\": [ \"amazonAlexa\" ] }, \"voiceModels\": { \"amazonAlexa\": { \"requiredPackages\": [ \"amazon.alexapr\", \"amazon.alexa.view\", \"amazon.alexa.adapter\" ], \"supportedLanguages\": { \"nlp\": { \"en-CA\": \"en-CA\", \"en-US\": \"en-US\", \"es-PR\": \"es-MX\", \"es-SV\": \"es-MX\", \"en-PR\": \"en-US\", \"es-UY\": \"es-MX\", \"es-BO\": \"es-MX\", \"es-GT\": \"es-MX\", \"es-VE\": \"es-MX\", \"en-JP\": \"en-US\", \"es-PY\": \"es-MX\", \"es-
": \"http:\\/\\/ngfts.lge.com\\/fts\\/gftsDownload.lge?biz_code=NLP&func_code=NLP_ICON&file_path=\\/nlp\\/icon_img\\/launch_browser_n.png\", \"focused\": \"http:\\/\\/ngfts.lge.com\\/fts\\/gftsDownload.lge?biz_code=NLP&func_code=NLP_ICON&file_path=\\/nlp\\/icon_img\\/launch_browser_f.png\", \"selected\": \"http:\\/\\/ngfts.lge.com\\/fts\\/gftsDownload.lge?biz_code=NLP&func_code=NLP_ICON&file_path=\\/nlp\\/icon_img\\/launch_browser_s.png\", \"disabled\": \"http:\\/\\/ngfts.lge.com\\/fts\\/gftsDownload.lge?biz_code=NLP&func_code=NLP_ICON&file_path=\\/nlp\\/icon_img\\/launch_browser_d.png\" } }, \"cagConfig\": { \"serverUrl\": \"https:\\/\\/he-us-ai.lgthinq.com:443\", \"asrEngine\": { \"nBest\": \"3\", \"enablePartialResult\": True, \"enablePcmDump\": False, \"enableDeveloperOption\": False, \"engine\": \"nuance\", \"appName\": \"com.lge.he.thinqtv\", \"customKey\": \"13716bef-16f3bd6b05baae43d3cce5e62d5dd80ace5-a56cb6cc5a6a57692c08f\" }, \"languageCode\": { \"ar-AE\": \"ar-AE\", \"ar-EG\": \"ar-EG\", \"ar-SA\": \"ar-SA\", \"cs-CZ\": \"cs-CZ\", \"zh-Hans-CN\": \"zh-CN\", \"zh-Hant-TW\": \"zh-TW\", \"da-DK\": \"da-DK\", \"de-DE\": \"de-DE\", \"el-GR\": \"el-GR\", \"en-AU\": \"en-AU\", \"en-GB\": \"en-GB\", \"en-IN\": \"en-IN\", \"en-US\": \"en-US\", \"en-CA\": \"en-CA\", \"fi-FI\": \"fi-FI\", \"fr-CA\": \"fr-CA\", \"fr-FR\": \"fr-FR\", \"he-IL\": \"he-IL\", \"hr-HR\": \"hr-HR\", \"hu-HU\": \"hu-HU\", \"id-ID\": \"id-ID\", \"it-IT\": \"it-IT\", \"ja-JP\": \"ja-JP\", \"ko-KR\": \"ko-KR\", \"nl-NL\": \"nl-NL\", \"nb-NO\": \"nb-NO\", \"pl-PL\": \"pl-PL\", \"pt-BR\": \"pt-BR\", \"pt-PT\": \"pt-PT\", \"ro-RO\": \"ro-RO\", \"ru-RU\": \"ru-RU\", \"sk-SK\": \"sk-SK\", \"es-ES\": \"es-ES\", \"es-MX\": \"es-MX\", \"sv-SE\": \"sv-SE\", \"th-TH\": \"th-TH\", \"tr-TR\": \"tr-TR\", \"uk-UA\": \"uk-UA\", \"vi-VN\": \"vi-VN\", \"zh-Hant-HK\": \"zh-HK\", \"ms-MY\": \"ms-MY\", \"hi-IN\": \"hi-IN\" } } }"
    }
}

print(len(data))
res = data['serverResponse']['response']
a = eval(res)
# Out:
# 2

# %%
for key in a.keys() :
    print(f'{key} : {a[key]}')
    print()
# Out:
# voiceFramework : {'voiceKeyBindings': {'webOSVoice': ['thinQtv'], 'webOSAmazon': ['amazonAlexa']}, 'voiceModels': {'amazonAlexa': {'requiredPackages': ['amazon.alexapr', 'amazon.alexa.view', 'amazon.alexa.adapter'], 'supportedLanguages': {'nlp': {'en-CA': 'en-CA', 'en-US': 'en-US', 'es-PR': 'es-MX', 'es-SV': 'es-MX', 'en-PR': 'en-US', 'es-UY': 'es-MX', 'es-BO': 'es-MX', 'es-GT': 'es-MX', 'es-VE': 'es-MX', 'en-JP': 'en-US', 'es-PY': 'es-MX', 'es-CL': 'es-MX', 'en-MX': 'en-US', 'es-DO': 'es-MX', 'es-MX': 'es-MX', 'fr-CA': 'fr-CA', 'es-CO': 'es-US', 'es-PE': 'es-MX', 'es-AR': 'es-MX', 'es-CA': 'es-MX', 'es-US': 'es-US', 'en-PH': 'en-US', 'es-NI': 'es-MX'}}, 'components': {'allInOneVoiceUi': 'amazon.alexapr', 'textNlpEngine': 'amazon.alexa.adapter.plugin', 'voiceNlpEngine': 'amazon.alexa.adapter.plugin'}, 'default': False}, 'thinQtv': {'requiredPackages': ['lg.thinqai', 'com.webos.service.voice.performer', 'com.webos.app.voice'], 'supportedLanguages': {'stt': {'en-IE': 'en-GB', 'ms-MY': 
# ...

# %%
a['magicLink']['supportedByTipsServer'] == True
# Out:
# True

# %%
data = {
    "returnValue": True,
    "serverResponse": {
        "code": "200",
        "message": "OK",
        "response": "{ \"epg_info\": [ { \"id\": \"base_epg_online\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"cdp_local_channel\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"cdp_support\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"guide_detail\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"iepg_merged\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ip_ch_map\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ip_epg\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ip_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ott_ch_map\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ott_epg\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"pbs_ibs_auth\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_acr_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_ch_map\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_epg\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_scd_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_uei_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"tuner_ch_map\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"tuner_epg\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"watch_flag\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null } ] }"
    }
}

flag = 'N'
# res = data['serverResponse']['response']
# res = res.replace('null', '""')
dd = eval(data['serverResponse']['response'].replace('null', '""'))['epg_info']
tuner_result = {}
result = {}

# %%
data = {
    "returnValue": true,
    "serverResponse": {
        "code": "200",
        "message": "OK",
        "response": "{ \"epg_info\": [ { \"id\": \"base_epg_online\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"cdp_local_channel\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"cdp_support\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"guide_detail\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"iepg_merged\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ip_ch_map\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ip_epg\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ip_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ott_ch_map\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"ott_epg\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"pbs_ibs_auth\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_acr_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_ch_map\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_epg\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_scd_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"stb_uei_watch_flag\", \"blacklistAppId\": [ ], \"isActive\": True, \"app_id\": null, \"launch_param\": null }, { \"id\": \"tuner_ch_map\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"tuner_epg\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null }, { \"id\": \"watch_flag\", \"blacklistAppId\": [ ], \"isActive\": False, \"app_id\": null, \"launch_param\": null } ] }"
    }
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 2
#       1 data = {
# ----> 2     "returnValue": true,
#       3     "serverResponse": {
#       4         "code": "200",
#       5         "message": "OK",
# ...

# %%
for d in dd : 
    if d['id'] == 'tuner_ch_map' or d['id'] == 'tuner_epg' :
        if d['isActive'] == False :
            tuner_result[d['id']] = d['isActive']
            flag = 'Y'
        else :
            tuner_result[d['id']] = d['isActive']
            flag = 'N'

# %%
if flag == 'Y' :
    result = {'returnValue' : {
                            'Result' : True,
                            'epgInfo' : tuner_result
                            } 
            }
else :
    result = {'returnValue' : {
                            'Result' : False,
                            'epgInfo' : tuner_result
                            } 
            }

# %%
print(json.dumps(result, indent=4))
# Out:
# {
#     "returnValue": {
#         "Result": true,
#         "epgInfo": {
#             "tuner_ch_map": false,
#             "tuner_epg": false
#         }
#     }
# }
